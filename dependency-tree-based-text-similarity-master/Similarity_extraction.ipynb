# %%
import spacy
from nltk.corpus import wordnet as wn
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/dell/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
np = spacy.load('en_core_web_sm')

# %%
def drawSent(sent):
    parsed = np(sent)
    spacy.displacy.render(parsed, jupyter=True)

# %%
drawSent("What are the common symptoms of COVID-19?")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="070d56de128b4750940d91e433a0f926-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
drawSent("Headache, General weakness, Cough, Loss of smell and taste, Vomiting and difficulty breathing")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="57e3e1b444cd4272ac41b9e45d75c618-0" class="displacy" width="2325" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Headache,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">General</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
drawSent("How is COVID 19 passed or transmitted to people?")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a6f758719ca948d68cb8cbd4b14fada1-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">How</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
drawSent("It is transmitted by respiratory droplets that contain the virus.")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="14ae4a841fa04484b460a40b9f5c9832-0" class="displacy" width="1800" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
import TextSimilarity as TS
import numpy as np

# %%
tag_correlation_matrix =np.load('models/abc.npy')

# %%
import json
with open("data/tags.json","r") as fl:
    tags = json.load(fl)

# %%
ts1 = TS.TextSimilarity(tags,tag_correlation_matrix)

# %%
ts1.semantic_similarity("The problem likely will mean corrective changes before the shuttle fleet starts flying again.", 
                        "He said the problem needs to be corrected before the space shuttle fleet is cleared to fly again.")
# Out:
# 0.2844434481735702

# %%
#1,"The technology-laced Nasdaq Composite Index .IXIC inched down 1 point, or 0.11 percent, to 1,650.","The broad Standard & Poor's 500 Index .SPX inched up 3 points, or 0.32 percent, to 970.",0.16
ts1.semantic_similarity("The technology-laced Nasdaq Composite Index .IXIC inched down 1 point, or 0.11 percent, to 1,650.", 
                        "he broad Standard & Poor's 500 Index .SPX inched up 3 points, or 0.32 percent, to 970.")
# Out:
# 0.2653377141603286

# %%
qs1 = "How is COVID 19 passed or transmitted to people?"
sent1 = "It is transmitted by respiratory droplets that contain the virus."
ts1.semantic_similarity(qs1, 
                        sent1)
# Out:
# -0.003562386358036562

# %%
qs1 = "What are the common symptoms of COVID-19?"
sent1 = "It is transmitted by respiratory droplets that contain the virus."
ts1.semantic_similarity(qs1, 
                        sent1)
# Out:
# 0.009763167537395348

# %%
import pickle
def mkPikle(filename, content):
    with open(filename, 'wb') as f:
        pickle.dump(content, f)
        f.close()
        
def rdPickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
survey_df_sentences = rdPickle('pickle/survey_df_sentences.pkl')
rf_df_sentences     = rdPickle('pickle/rf_df_sentences.pkl')
np_qs_df            = rdPickle('pickle/np_qs_df.pkl')
np_ref_df           = rdPickle('pickle/np_ref_df.pkl')

# %%
# We will create the same type of output but now instead of considering all the sentences,
# will consider sentences individually

import csv

# Creading a CSV writer 
outFile = open('report_Dep_tree.csv', 'w')
writer_rep = csv.writer(outFile)

# Middle portion

lst_ref = []
lst_pas = []

#for col in qs_df.columns:
for col in range(len(np_qs_df)):
    # Clear it 
    lst_ref = []
    lst_pas = []
    
    print("=====================================")
    print("Question : ", np_qs_df[col])
    writer_rep.writerow(())
    writer_rep.writerow(('Question',  
                     np_qs_df[col], 
                     '',
                     ''))
    print("Reference text : ", np_ref_df[col])

    writer_rep.writerow(('Reference text',  
                     np_ref_df[col], 
                     '',
                     ''))
    writer_rep.writerow(())
    
    writer_rep.writerow(('Serial', 
                     'Reference text', 
                     'User Text', 
                     'Score'))
    
    for row in range(len(survey_df_sentences)):
        
        print(row, len(rf_df_sentences[col]))
        lst_pas = survey_df_sentences[row][col]
        print(survey_df_sentences[row][col], len(survey_df_sentences[row][col]))
        
        
        for ref_part in range(len(rf_df_sentences[col])):
            q_part_txt= rf_df_sentences[col][ref_part]
            
            #     # Getting the embedding
            #q_emb = model_p.encode(q_part_txt)
            #p_emb = model_p.encode(lst_pas)
            #     # Printing the similarity score 
            #print("Similarity on bigger:", util.pytorch_cos_sim(q_emb, p_emb))
            #sim_score = util.pytorch_cos_sim(q_emb, p_emb).cpu().detach().numpy()[0]
            
            i = 0 
            
            # Writing in the File
            for pass_text in lst_pas:
                score = ts1.semantic_similarity(q_part_txt, pass_text)
                writer_rep.writerow((row+1, 
                             q_part_txt, 
                             pass_text, 
                             score))
                i = i + 1
        
# Closing the output file
outFile.close()
# Out:
# ...
# Question :  4. What are the common symptoms of COVID-19?
# Reference text :  Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing
# 0 1
# ['COMMON SYMPTOMS Fever Cough General malaise Loss of taste or smell UN COMMON SYMPTOMS: Sore throat Headache Diarrhea Skin rash Irritated eyes SYMPTOMS - COMPLICATIONS: Difficulty breathing or dyspnea Lethargy Chest pain'] 1
# 1 1
# ['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing'] 1
# 2 1
# ['Flu-like symptoms plus loss of taste and smell.', 'Also pain in the lung area and shortness of breath'] 2
# 3 1
# ['Cough, fever, myalgia, dyspnea, malaise.'] 1
# ...
# Question :  19. Have you had any discomfort after vaccination?
# Reference text :  fever and muscle pain
# 0 1
# ['Yes, general malaise for 1 night .'] 1
# 1 1
# ['Yes, in the second vaccination I had a fever and muscle pain.'] 1
# 2 1
# ['Pain at the injection site'] 1
# 3 1
# ...
